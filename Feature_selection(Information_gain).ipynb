# %%
import pandas as pd
df=pd.read_csv('house_price.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
numeric_lst=['int16','int32','int64','float16','float32','float64']
numerical_col=list(df.select_dtypes(include=numeric_lst).columns)

# %%
df=df[numerical_col]

# %%
df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  OpenPorchSF  \
# 0          2003       196.0         706  ...           0           61
# 1          1976         0.0         978  ...         298            0
# 2          2002       162.0         486  ...           0           42
# 3          1970         0.0         216  ...           0           35
# 4          2000       350.0         655  ...         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %%
df=df.drop("Id",axis=1)

# %%
df
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60         65.0     8450            7            5       2003
# 1             20         80.0     9600            6            8       1976
# 2             60         68.0    11250            7            5       2001
# 3             70         60.0     9550            7            5       1915
# 4             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1455          60         62.0     7917            6            5       1999
# 1456          20         85.0    13175            6            6       1978
# 1457          70         66.0     9042            7            9       1941
# 1458          20         68.0     9717            5            6       1950
# 1459          20         75.0     9937            5            6       1965
#
# ...

# %%
#It is always a good practice to split train and test data to avoid overfitting

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.drop(labels=['SalePrice'],axis=1),df['SalePrice'],test_size=0.3,random_state=0)

# %%
X_train
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 64            60          NaN     9375            7            5       1997
# 682          120          NaN     2887            6            5       1996
# 960           20         50.0     7207            5            7       1958
# 1384          50         60.0     9060            6            5       1939
# 1100          30         60.0     8400            2            5       1920
# ...          ...          ...      ...          ...          ...        ...
# 763           60         82.0     9430            8            5       1999
# 835           20         60.0     9600            4            7       1950
# 1216          90         68.0     8930            6            5       1978
# 559          120          NaN     3196            7            5       2003
# 684           60         58.0    16770            7            5       1998
#
# ...

# %%
from sklearn.feature_selection import mutual_info_regression
#determine the mutual information
mutual_info = mutual_info_regression(X_train.fillna(0),y_train)
mutual_info
# Out:
# array([2.57673020e-01, 2.09919675e-01, 1.63478663e-01, 5.38997618e-01,
#        1.06488018e-01, 3.41703136e-01, 2.43322001e-01, 9.78125595e-02,
#        1.66213595e-01, 1.12778216e-02, 1.12635659e-01, 3.86382920e-01,
#        3.09998167e-01, 2.23173559e-01, 0.00000000e+00, 4.82226087e-01,
#        2.85636282e-02, 7.31614728e-03, 2.55981006e-01, 7.91901588e-02,
#        4.26143118e-02, 2.16341935e-02, 1.84473119e-01, 1.84512906e-01,
#        2.63604991e-01, 3.72939468e-01, 3.64628014e-01, 7.34617815e-02,
#        1.75238129e-01, 1.75078761e-02, 5.24396718e-04, 2.50679481e-02,
#        1.83049442e-03, 1.29383313e-02, 0.00000000e+00, 6.07601154e-03])

# %%
mutual_info = pd.Series(mutual_info)
mutual_info.index=X_train.columns
mutual_info.sort_values(ascending=False)
# Out:
# OverallQual      0.538998
# GrLivArea        0.482226
# TotalBsmtSF      0.386383
# GarageCars       0.372939
# GarageArea       0.364628
# YearBuilt        0.341703
# 1stFlrSF         0.309998
# GarageYrBlt      0.263605
# MSSubClass       0.257673
# FullBath         0.255981
# YearRemodAdd     0.243322
# 2ndFlrSF         0.223174
# LotFrontage      0.209920
# Fireplaces       0.184513
# TotRmsAbvGrd     0.184473
# OpenPorchSF      0.175238
# BsmtFinSF1       0.166214
# LotArea          0.163479
# BsmtUnfSF        0.112636
# OverallCond      0.106488
# MasVnrArea       0.097813
# HalfBath         0.079190
# WoodDeckSF       0.073462
# BedroomAbvGr     0.042614
# BsmtFullBath     0.028564
# ScreenPorch      0.025068
# KitchenAbvGr     0.021634
# EnclosedPorch    0.017508
# MiscVal          0.012938
# BsmtFinSF2       0.011278
# BsmtHalfBath     0.007316
# YrSold           0.006076
# PoolArea         0.001830
# 3SsnPorch        0.000524
# LowQualFinSF     0.000000
# ...

# %%
mutual_info.sort_values(ascending=False).plot.bar(figsize=(15,5))
# Out:
# <Axes: >

# %%
from sklearn.feature_selection import SelectPercentile

selected_top_columns=SelectPercentile(mutual_info_regression,percentile=20)
selected_top_columns.fit(X_train.fillna(0),y_train)
X_train.columns[selected_top_columns.get_support()]
# Out:
# Index(['OverallQual', 'YearBuilt', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea',
#        'GarageCars', 'GarageArea'],
#       dtype='object')

# %% [markdown]
# ## Fisher Score--Chisquare Test For Feature Selection

# %% [markdown]
# Compute chi-squared stats between each non-negative feature and class
#
# This score should be used to evaluate categorical variables in a classification task.
#
# This score can be used to select the n-features with the highest values for the test chi-squared statistic from X, which must contain only non-negative features such as booleans or frequencies (e.g term counts in document classification ) relative to the classes.
#
# Recall that the chi-square test measures dependencies between stochastic variables , so using this function 'weeds out' the features that are the most likely to be independent of class and therefore irrelevent for classification. The chi square statistics is commonly used for testing relationships between categorical variables.
#
# It compares the observed distribution of the different classes of the target Y among the different categories of the features, against the expected distribution of the target classes, regardless of the feature categories

# %%
import seaborn as sns

# %%
import pandas as pd
import seaborn as sns
import ssl

# Disable SSL certificate verification (not recommended for production)
ssl._create_default_https_context = ssl._create_unverified_context

# Load the Titanic dataset
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
 df=df[['sex','embarked','alone','pclass','survived']]
df.head()
# Out:
#       sex embarked  alone  pclass  survived
# 0    male        S  False       3         0
# 1  female        C  False       1         1
# 2  female        S   True       3         1
# 3  female        S  False       1         1
# 4    male        S   True       3         0

# %%
import numpy as np

# %%
# lets perform label encoding
df['sex']=np.where(df['sex']=="male",1,0)

# %%
#perform label encoding on embarked
ordinal_label={k:i for i,k in enumerate(df['embarked'].unique(),0)}
df['embarked']=df['embarked'].map(ordinal_label)

# %%
df.head()
# Out:
#    sex  embarked  alone  pclass  survived
# 0    1         0  False       3         0
# 1    0         1  False       1         1
# 2    0         0   True       3         1
# 3    0         0  False       1         1
# 4    1         0   True       3         0

# %%
#perform label encoding on alone
df['alone']=np.where(df['alone']== True ,1,0)

# %%
df
# Out:
#      sex  embarked  alone  pclass  survived
# 0      1         0      0       3         0
# 1      0         1      0       1         1
# 2      0         0      1       3         1
# 3      0         0      0       1         1
# 4      1         0      1       3         0
# ..   ...       ...    ...     ...       ...
# 886    1         0      1       2         0
# 887    0         0      1       1         1
# 888    0         0      0       3         0
# 889    1         1      1       1         1
# 890    1         2      1       3         0
#
# [891 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df[['sex','embarked','alone','pclass']],df['survived'],test_size=0.3,random_state=0)

# %%
X_train.head()
# Out:
#      sex  embarked  alone  pclass
# 857    1         0      1       1
# 52     0         1      0       1
# 386    1         0      0       3
# 124    1         0      0       1
# 578    0         1      0       3

# %%
df['sex'].unique()
# Out:
# array([1, 0])

# %%
#performing chi2 test
# chi2 returns 2 values
# F score and p value
from sklearn.feature_selection import chi2
f_p_values=chi2(X_train,y_train)

# %%
f_p_values
# Out:
# (array([63.55447864, 11.83961845,  9.03328564, 21.61080949]),
#  array([1.55992554e-15, 5.79837058e-04, 2.65107556e-03, 3.33964360e-06]))

# %%
#higher the value of f score the more important is the feature
# lower the value of p value the more important is the feature

# %%
p_values=pd.Series(f_p_values[1])
p_values.index=X_train.columns
p_values
# Out:
# sex         1.559926e-15
# embarked    5.798371e-04
# alone       2.651076e-03
# pclass      3.339644e-06
# dtype: float64

# %%
p_values.sort_index(ascending=False)
# Out:
# sex         1.559926e-15
# pclass      3.339644e-06
# embarked    5.798371e-04
# alone       2.651076e-03
# dtype: float64

# %% [markdown]
# Observation:
#
#    Sex column is the most important column when compared to the output feature survived
