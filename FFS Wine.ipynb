# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from mlxtend.feature_selection import SequentialFeatureSelector
import pandas as pd

# %%
from sklearn.datasets import load_wine

# %%
data=load_wine()
df=pd.DataFrame(data.data,columns=data.feature_names)

# %%
y=data.target

# %%
y=pd.DataFrame(y)

# %%
X.shape

X=df.iloc[:,0:14]

# %%
X.shape
# Out:
# (178, 13)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)

# %%
classifier=RandomForestClassifier(n_jobs=-1)
features=6

# %%
feature_selector=SequentialFeatureSelector(classifier,
                                          k_features=features,
                                          forward=True,
                                          scoring='accuracy',
                                          cv=5)

# %%
feature_selector.fit(X_train,y_train)
# Out:
# /home/akshay/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/akshay/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/akshay/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
feature_selector.k_feature_names_
# Out:
# ('alcohol',
#  'flavanoids',
#  'proanthocyanins',
#  'color_intensity',
#  'od280/od315_of_diluted_wines',
#  'proline')

# %%
selected=feature_selector.k_feature_names_

# %%
final_model=RandomForestClassifier(n_jobs=-1)

# %%
list(feature_selector.k_feature_idx_)
# Out:
# [0, 6, 8, 9, 11, 12]

# %%
final_model.fit(X_train.iloc[:,list(feature_selector.k_feature_idx_)],y_train)
# Out:
# /tmp/ipykernel_5887/404838509.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   final_model.fit(X_train.iloc[:,list(feature_selector.k_feature_idx_)],y_train)
# RandomForestClassifier(n_jobs=-1)

# %%
predictions=final_model.predict(X_test.iloc[:,list(feature_selector.k_feature_idx_)])

# %%
accuracy=accuracy_score(y_test,predictions)

# %%
accuracy
# Out:
# 0.9629629629629629
